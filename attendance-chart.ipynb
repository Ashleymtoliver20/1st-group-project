# %%
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("NFL/panthers and steelers attendence .csv")
df.head(20)
# Out:
#        Carolina Panthers  Week 1  Week 2  Week 3  Week 4  Week 5  Week 6  \
# 0                   2015  60,733  73,254  73,402  57,468     Bye  69,020
# 1                   2016  76,843  74,143  73,813  70,508  73,425  73,138
# 2                   2017  70,178  74,122  73,775  65,878  64,288  74,373
# 3                   2018  74,532  72,528  72,161     Bye  74,221  60,482
# 4                   2019  72,005  71,101  60,104  71,699  72,762  60,087
# 5                   2020       0       0       0   5,120   6,656   5,240
# 6                   2021  70,211  70,675  68,320  93,262  72,545  72,104
# 7   Pittsburgh Steelers   Week 1  Week 2  Week 3  Week 4  Week 5  Week 6
# 8                   2015  66,829  66,472  52,433  63,929  67,658  63,846
# 9                   2016  79,124  65,072  69,596  61,278  66,385  65,351
# 10                  2017  67,431  65,971  61,172  71,126  66,237  76,994
# 11                  2018  67,431  63,956  62,571  62,030  64,781  60,594
# ...

# %%
panthers_2015 = [60733, 73254, 73402, 57468, 0, 69020, 74194, 74136, 74461, 63591, 74418, 90909, 73097, 74420, 79436, 70981, 74169, 0]
steelers_2015 = [66829, 66472, 52433, 63929, 67658, 63846, 76365, 64750, 65520, 64402, 0, 69055, 58701, 65564, 67234, 71261, 66693, 0]


weeks = range(1,19)
width = 0.5
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(weeks, panthers_2015, width, label='Carolina Panthers')
rects2 = ax.bar([x+width for x in weeks], steelers_2015, width, label='Pittsburgh Steelers')


ax.set_xlabel('Weeks')
ax.set_ylabel('Attendance')
ax.set_title('Weekly attendance for Carolina Panthers and Pittsburgh Steelers in 2015')
ax.set_xticks([i+0.5*width for i in weeks])
ax.set_xticklabels(weeks)
ax.legend()

plt.show()

# %%
panthers_2016 = [76843,74143,73813,70508,73425,73138, 0,74088,86109,74181,73288,54909,69104,73856,76689,73549,62037,0]
steelers_2016 = [79124,65072,69596,61278,66385,65351,66009,0,71286,67737,67431,66583,65825,69657,62096,66276,55921,0]

weeks = range(1,19)
width = 0.5
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(weeks, panthers_2016, width, label='Carolina Panthers')
rects2 = ax.bar([x+width for x in weeks], steelers_2016, width, label='Pittsburgh Steelers')


ax.set_xlabel('Weeks')
ax.set_ylabel('Attendance')
ax.set_title('Weekly attendance for Carolina Panthers and Pittsburgh Steelers in 2016')
ax.set_xticks([i+0.5*width for i in weeks])
ax.set_xticklabels(weeks)
ax.legend()

plt.show()

# %%
panthers_2017 = [70178,74122,73775,65878,64288,74373,61256,58545,74244,72790,0,77562,73171,73728,74447,71463,74141,0]
steelers_2017 = [67431,65971,61172,71126,66237,76994,65363,64983,0,66146,60703,62147,56029,60069,68574,71842,50704,0]

weeks = range(1,19)
width = 0.5
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(weeks, panthers_2017, width, label='Carolina Panthers')
rects2 = ax.bar([x+width for x in weeks], steelers_2017, width, label='Pittsburgh Steelers')


ax.set_xlabel('Weeks')
ax.set_ylabel('Attendance')
ax.set_title('Weekly attendance for Carolina Panthers and Pittsburgh Steelers in 2017')
ax.set_xticks([i+0.5*width for i in weeks])
ax.set_xticklabels(weeks)
ax.legend()

plt.show()

# %%
panthers_2018 = [74532,72528,72161,0,74221,60482,69696,73843,73513,62881,61999,74002,52568,59392,74188,73722,73028,0]
steelers_2018 = [67431,63956,62571,62030,64781,60594,0,63780,70997,62881,67683,76536,61069,53960,65280,73086,63874,0]

weeks = range(1,19)
width = 0.5
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(weeks, panthers_2018, width, label='Carolina Panthers')
rects2 = ax.bar([x+width for x in weeks], steelers_2018, width, label='Pittsburgh Steelers')


ax.set_xlabel('Weeks')
ax.set_ylabel('Attendance')
ax.set_title('Weekly attendance for Carolina Panthers and Pittsburgh Steelers in 2018')
ax.set_xticks([i+0.5*width for i in weeks])
ax.set_xticklabels(weeks)
ax.legend()

plt.show()

# %%
panthers_2019 = [72005,71101,60104,71699,72762,60087,0,69083,72540,78090,73106,73068,71504,70592,72544,61845,72203,0]
steelers_2019 = [65878,65063,69439,57959,64037,25425,0,59244,61115,63627,67431,47423,62157,63880,64694,78523,70695,0]

weeks = range(1,19)
width = 0.5
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(weeks, panthers_2019, width, label='Carolina Panthers')
rects2 = ax.bar([x+width for x in weeks], steelers_2019, width, label='Pittsburgh Steelers')


ax.set_xlabel('Weeks')
ax.set_ylabel('Attendance')
ax.set_title('Weekly attendance for Carolina Panthers and Pittsburgh Steelers in 2019')
ax.set_xticks([i+0.5*width for i in weeks])
ax.set_xticklabels(weeks)
ax.legend()

plt.show()

# %%
panthers_2020 = [0,0,0,5120,6656,5240,3000,5240,12073,5815,5546,0,0,5768,0,0,1500,0]
steelers_2020 = [0,0,0,0,4708,5260,10355,4345,31700,5909,17244,0,0,0,10249,0,11989,0]

weeks = range(1,19)
width = 0.5
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(weeks, panthers_2020, width, label='Carolina Panthers')
rects2 = ax.bar([x+width for x in weeks], steelers_2020, width, label='Pittsburgh Steelers')


ax.set_xlabel('Weeks')
ax.set_ylabel('Attendance')
ax.set_title('Weekly attendance for Carolina Panthers and Pittsburgh Steelers in 2020')
ax.set_xticks([i+0.5*width for i in weeks])
ax.set_xticklabels(weeks)
ax.legend()

plt.show()

# %%
panthers_2021 = [70211,70675,68320,93262,72545,72104,71889,68583,72203,62400,73350,62389,0,72243,65398,71918,69170,65473]
steelers_2021 = [69787,63707,58076,78281,59841,60821,0,67431,60788,58716,70240,63238,59303,66718,59521,73371,63624,70453]

weeks = range(1,19)
width = 0.5
fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(weeks, panthers_2021, width, label='Carolina Panthers')
rects2 = ax.bar([x+width for x in weeks], steelers_2021, width, label='Pittsburgh Steelers')


ax.set_xlabel('Weeks')
ax.set_ylabel('Attendance')
ax.set_title('Weekly attendance for Carolina Panthers and Pittsburgh Steelers in 2021')
ax.set_xticks([i+0.5*width for i in weeks])
ax.set_xticklabels(weeks)
ax.legend()

plt.show()
